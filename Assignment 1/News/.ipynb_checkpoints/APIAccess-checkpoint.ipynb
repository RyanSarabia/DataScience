GMT","sub_articles":[],"source":{"href":"https://www.nytimes.com","title":"The New York Times"}},{"id":"CAIiEG4CTKgWWZcOD08PmHBlaK4qFwgEKg8IACoHCAowjuuKAzCWrzww54UY","title":"The T List: Five Things We Recommend This Week - The New York Times","link":"https://www.nytimes.com/2021/03/11/t-magazine/yuri-shimojo-mister-juis.html","published":"Thu, 11 Mar 2021 14:00:09 GMT","sub_articles":[],"source":{"href":"https://www.nytimes.com","title":"The New York Times"}},{"id":"CAIiEMtIdUIjD3CM0Wt50eFRxWUqFwgEKg8IACoHCAowjuuKAzCWrzwwt4QY","title":"China Turns to Elon Musk as Technology Dreams Sour - The New York Times","link":"https://www.nytimes.com/2021/03/11/technology/china-elon-musk-fans.html","published":"Thu, 11 Mar 2021 15:29:33 GMT","sub_articles":[],"source":{"href":"https://www.nytimes.com","title":"The New York Times"}},{"id":"CAIiEAwLF3ExC932HkHapycyxgQqFwgEKg8IACoHCAowjuuKAzCWrzww9oAY","title":"Counting the Toll of the Pandemic, by the Numbers - The New York Times","link":"https://www.nytimes.com/2021/03/11/business/dealbook/pandemic-numbers-toll.html","published":"Thu, 11 Mar 2021 13:09:18 GMT","sub_articles":[],"source":{"href":"https://www.nytimes.com","title":"The New York Times"}},{"id":"CBMiTGh0dHBzOi8vd3d3Lm55dGltZXMuY29tL2ludGVyYWN0aXZlLzIwMjEvMDMvMTEvcmVhbGVzdGF0ZS8xMWh1bnQtZ2FmZmllLmh0bWzSAQA","title":"He Tested Manhattan's Rental Market Mid-Pandemic. But What Could He Find for Less Than $3000? - The New York Times","link":"https://www.nytimes.com/interactive/2021/03/11/realestate/11 ...

# %% [markdown]
# Since the full article is not included, the link is taken from the articles and will be opened in another cell

# %%
import json
import requests

jsonNews = json.loads(data.decode("utf-8"))
jsonNews = jsonNews.get('articles')
links = []
requestedLinks = []

for i in range(len(jsonNews)):
    links.append(jsonNews[i].get('link'))
    temp = requests.get(links[i])
    requestedLinks.append(temp.content)

# %% [markdown]
# Here, BeautifulSoup is imported and is used to parse the content of the links

# %%
from bs4 import BeautifulSoup

soup = []
for i in range(len(links)):
    soup.append(BeautifulSoup(requestedLinks[i], 'html.parser'))

# %% [markdown]
# The needed info is taken from the initial requested data, and the authors and full article are scraped from the page in the link. The info is appended into an array of json objects.

# %%
jsonNewsExtracted = []
for i in range(len(jsonNews)):
    date = jsonNews[i].get('published')
    title = jsonNews[i].get('title')
    allAuthors = ""
    authors = soup[i].find_all("span", itemprop="name")
    for i in range (len(authors)):
        if i != len(authors)-1:
            allAuthors = allAuthors + authors[i].text + ', '
        else:
            allAuthors = allAuthors + authors[i].text
    try:
        full_article = soup[i].find(id = 'story').find('section').text
    except:
        pass
    jsonNewsExtracted.append({
            "date": date,
            "title": title,
            "full_article": full_article,
            "authors": allAuthors
        })

# %% [markdown]
# The json object array is exported as news.json

# %%
json_dump = json.dumps(jsonNewsExtracted, indent = 4) 

with open("news.json", "w") as outfile:
    outfile.write(json_dump)
